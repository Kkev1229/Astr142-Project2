# %%
from proj2_runfile import HUDF_Plotter
import importlib
import proj2_runfile
importlib.reload(proj2_runfile)
# Out:
# <module 'proj2_runfile' from '/mnt/c/Users/kevin/Documents/UCLA/astr142/proj2/proj2_runfile.py'>

# %%
catalog_ids = ['J/AJ/150/31/table5', 'J/A+A/608/A2/combined']
zcols = ['zph1', 'zMuse']

# %%
hudfp = HUDF_Plotter()
# Out:
# INFO: Loading Hubble UDF fits files...
# INFO:   Loading i image
# INFO:   Loading v image
# INFO:   Loading b image
# INFO: Finished loading.
# INFO: Converting to RGB image...

# %%
hudfp.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <WCSAxesSubplot:xlabel='RA (deg)', ylabel='DEC (deg)'>)

# %%
hudfp.add_z_catalog(catalog_ids[0], zcols[0], mag_constraint=25, color='y')
hudfp.add_z_catalog(catalog_ids[1], zcols[1], mag_constraint=25, color='m')

# %%
hudfp.cross_match_catalogs(catalog_ids[0], catalog_ids[1])
# Out:
# INFO: Key for cross-matched catalog not specified. Defaulting to J/AJ/150/31/table5_J/A+A/608/A2/combined

# %%
hudfp.plot_z_dist()
